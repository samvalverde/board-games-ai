# %%
# --- Celda 1: imports y carga de datos ---
import pandas as pd
import matplotlib.pyplot as plt

# Cargar resultados del benchmark
df = pd.read_csv("results.csv")

# Asegurarnos de que aborted sea booleano
df["aborted"] = df["aborted"].astype(bool)

df.head()

# poetry run jupyter notebook peg_solitaire/experiments/plots.ipynb
# Out:
#    heuristic  n  run  success      time  expanded  generated  max_frontier  \
# 0  min_moves  3    1     True  0.870621      6983       9960           892
# 1  min_moves  3    2     True  0.920482      6983       9960           892
# 2  min_moves  3    3     True  0.925049      6983       9960           892
# 3  min_moves  3    4     True  0.934095      6983       9960           892
# 4  min_moves  3    5     True  0.945722      6983       9960           892
#
#    solution_length  aborted
# 0             31.0    False
# 1             31.0    False
# 2             31.0    False
# 3             31.0    False
# 4             31.0    False

# %%
# --- Celda 2: Tiempo de ejecución promedio (incluye abortos) ---
times = df.groupby(["n", "heuristic"])["time"].mean().unstack()

times.plot(kind="bar", figsize=(8,5))
plt.title("⏱ Tiempo promedio por heurística (incluye abortos)")
plt.ylabel("Tiempo (s)")
plt.xlabel("Tamaño del tablero (n)")
plt.xticks(rotation=0)
plt.legend(title="Heurística")
plt.show()
# Out:
# c:\Users\jcval\AppData\Local\pypoetry\Cache\virtualenvs\board-games-T72EZuaj-py3.12\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9201 (\N{STOPWATCH}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# --- Celda 3: Tasa de éxito y abortos (barras apiladas) ---
success = df.groupby(["n", "heuristic"])["success"].mean().unstack()
abort = df.groupby(["n", "heuristic"])["aborted"].mean().unstack()

fig, ax = plt.subplots(figsize=(8,5))
(success * 100).plot(kind="bar", ax=ax, stacked=True, color=["#4CAF50","#2196F3","#FFC107"])
(abort * 100).plot(kind="bar", ax=ax, stacked=True, bottom=(success*100), alpha=0.6, color=["#FF9999","#FF6666","#CC0000"])

plt.title("✅ Éxito vs ⚠️ Abortos (%) por heurística")
plt.ylabel("Porcentaje de corridas")
plt.xlabel("Tamaño del tablero (n)")
plt.xticks(rotation=0)
plt.legend(["Éxito min_moves","Éxito manhattan","Éxito combo",
            "Abortos min_moves","Abortos manhattan","Abortos combo"], loc="upper right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 7
#       5 fig, ax = plt.subplots(figsize=(8,5))
#       6 (success * 100).plot(kind="bar", ax=ax, stacked=True, color=["#4CAF50","#2196F3","#FFC107"])
# ----> 7 (abort * 100).plot(kind="bar", ax=ax, stacked=True, bottom=(success*100), alpha=0.6, color=["#FF9999","#FF6666","#CC0000"])
#       9 plt.title("✅ Éxito vs ⚠️ Abortos (%) por heurística")
#      10 plt.ylabel("Porcentaje de corridas")
#
# File c:\Users\jcval\AppData\Local\pypoetry\Cache\virtualenvs\board-games-T72EZuaj-py3.12\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\jcval\AppData\Local\pypoetry\Cache\virtualenvs\board-games-T72EZuaj-py3.12\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\Users\jcval\AppData\Local\pypoetry\Cache\virtualenvs\board-games-T72EZuaj-py3.12\Lib\site-packages\pandas\plotting\_matplotlib\core.py:501, in MPLPlot.generate(self)
#     499 self._compute_plot_data()
#     500 fig = self.fig
# --> 501 self._make_plot(fig)
#     502 self._add_table()
#     503 self._make_legend()
#
# File c:\Users\jcval\AppData\Local\pypoetry\Cache\virtualenvs\board-games-T72EZuaj-py3.12\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1940, in BarPlot._make_plot(self, fig)
#    1938 start = np.where(mask, pos_prior, neg_prior) + self._start_base
#    1939 w = self.bar_width / 2
# -> 1940 rect = self._plot(
#    1941     ax,
#    1942     self.ax_pos + w,
#    1943     y,
#    1944     self.bar_width,
#    1945     start=start,
#    1946     label=label,
#    1947     log=self.log,
#    1948     **kwds,
#    1949 )
#    1950 pos_prior = pos_prior + np.where(mask, y, 0)
#    1951 neg_prior = neg_prior + np.where(mask, 0, y)
#
# File c:\Users\jcval\AppData\Local\pypoetry\Cache\virtualenvs\board-games-T72EZuaj-py3.12\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1884, in BarPlot._plot(cls, ax, x, y, w, start, log, **kwds)
#    1873 @classmethod
#    1874 def _plot(  # type: ignore[override]
#    1875     cls,
#    (...)   1882     **kwds,
#    1883 ):
# -> 1884     return ax.bar(x, y, w, bottom=start, log=log, **kwds)
#
# File c:\Users\jcval\AppData\Local\pypoetry\Cache\virtualenvs\board-games-T72EZuaj-py3.12\Lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File c:\Users\jcval\AppData\Local\pypoetry\Cache\virtualenvs\board-games-T72EZuaj-py3.12\Lib\site-packages\matplotlib\axes\_axes.py:2646, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2643 args = zip(left, bottom, width, height, facecolor, edgecolor, linewidth,
#    2644            hatch, patch_labels)
#    2645 for l, b, w, h, c, e, lw, htch, lbl in args:
# -> 2646     r = mpatches.Rectangle(
#    2647         xy=(l, b), width=w, height=h,
#    2648         facecolor=c,
#    2649         edgecolor=e,
#    2650         linewidth=lw,
#    2651         label=lbl,
#    2652         hatch=htch,
#    2653         )
#    2654     r._internal_update(kwargs)
#    2655     r.get_path()._interpolation_steps = 100
#
# File c:\Users\jcval\AppData\Local\pypoetry\Cache\virtualenvs\board-games-T72EZuaj-py3.12\Lib\site-packages\matplotlib\patches.py:772, in Rectangle.__init__(self, xy, width, height, angle, rotation_point, **kwargs)
#     748 @_docstring.interpd
#     749 def __init__(self, xy, width, height, *,
#     750              angle=0.0, rotation_point='xy', **kwargs):
#     751     """
#     752     Parameters
#     753     ----------
#    (...)    770         %(Patch:kwdoc)s
#     771     """
# --> 772     super().__init__(**kwargs)
#     773     self._x0 = xy[0]
#     774     self._y0 = xy[1]
#
# File c:\Users\jcval\AppData\Local\pypoetry\Cache\virtualenvs\board-games-T72EZuaj-py3.12\Lib\site-packages\matplotlib\patches.py:92, in Patch.__init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#      89 self._dash_pattern = (0, None)  # offset, dash (scaled by linewidth)
#      91 self.set_linestyle(linestyle)
# ---> 92 self.set_linewidth(linewidth)
#      93 self.set_antialiased(antialiased)
#      94 self.set_hatch(hatch)
#
# File c:\Users\jcval\AppData\Local\pypoetry\Cache\virtualenvs\board-games-T72EZuaj-py3.12\Lib\site-packages\matplotlib\patches.py:439, in Patch.set_linewidth(self, w)
#     437 if w is None:
#     438     w = mpl.rcParams['patch.linewidth']
# --> 439 self._linewidth = float(w)
#     440 self._dash_pattern = mlines._scale_dashes(
#     441     *self._unscaled_dash_pattern, w)
#     442 self.stale = True
#
# TypeError: only length-1 arrays can be converted to Python scalars

# %%
# --- Celda 4: Nodos expandidos promedio (éxitos y abortos separados) ---
expanded_success = df[df["success"]==True].groupby(["n","heuristic"])["expanded"].mean().unstack()
expanded_abort = df[df["aborted"]==True].groupby(["n","heuristic"])["expanded"].mean().unstack()

fig, ax = plt.subplots(1,2, figsize=(14,5), sharey=True)

expanded_success.plot(kind="bar", ax=ax[0])
ax[0].set_title("📦 Nodos expandidos (solo éxitos)")
ax[0].set_ylabel("Nodos expandidos")

expanded_abort.plot(kind="bar", ax=ax[1], color=["#FF9999","#FF6666","#CC0000"])
ax[1].set_title("📦 Nodos expandidos (abortos)")
ax[1].set_ylabel("Nodos expandidos")

plt.suptitle("Nodos expandidos promedio")
plt.show()

# %%
# --- Celda 5: Resumen tabular ---
summary = df.groupby(["n", "heuristic"]).agg(
    runs=("run", "count"),
    success_rate=("success", "mean"),
    abort_rate=("aborted", "mean"),
    avg_time=("time", "mean"),
    avg_expanded=("expanded", "mean")
)
summary
